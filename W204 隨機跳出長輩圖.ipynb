# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from IPython.display import display, Image
from numpy.random import randint

# %%
# %ls #檢查一下圖片有沒有在資料夾中
# Out:
#  磁碟區 C 中的磁碟是 Acer
#  磁碟區序號:  A475-1614
#
#  C:\大學\一下計算機 的目錄
#
# 2020/03/07  下午 10:54    <DIR>          .
# 2020/03/07  下午 10:54    <DIR>          ..
# 2020/03/07  下午 10:44    <DIR>          .ipynb_checkpoints
# 2020/03/04  上午 09:15               555 202020304.ipynb
# 2020/03/03  下午 04:19             1,608 W101匯率轉換.ipynb
# 2020/03/03  下午 08:27             2,362 W102小短文產生器.ipynb
# 2020/03/03  下午 08:27             2,765 W103一日三餐生成器.ipynb
# 2020/03/03  下午 08:26             3,020 W104比大小 (一次).ipynb
# 2020/03/07  下午 10:14             2,361 W201 小遊記生成器_做不出來....ipynb
# 2020/03/07  下午 10:21             1,770 W201 隨機出分數題.ipynb
# 2020/03/07  下午 10:41             5,882 W202 跟電腦比撲克牌大小(三次).ipynb
# 2020/03/07  下午 10:44             1,735 W203 計算日子間的日子.ipynb
# 2020/03/07  下午 10:54            14,969 W204.ipynb
# 2019/10/15  下午 09:24            34,838 長輩圖1.jpg
# 2019/10/15  下午 09:26            52,466 長輩圖2.jpg
# 2019/10/15  下午 09:27            53,227 長輩圖3.jpg
# ...

# %%
長輩圖1=Image('長輩圖1.jpg')
長輩圖2=Image('長輩圖2.jpg')
長輩圖3=Image('長輩圖3.jpg')
長輩圖4=Image('長輩圖4.png')
長輩圖5=Image('長輩圖5.jpg')
長輩圖6=Image('長輩圖6.jpg')  #png/jpg要看仔細呀!

# %%
X = randint(1,7,1)
if X == 1:
    display(長輩圖1)
if X == 2:
    display(長輩圖2)
if X == 3:
    display(長輩圖3)
if X == 4:
    display(長輩圖4)
if X == 5:
    display(長輩圖5)
if X == 6:
    display(長輩圖6)
